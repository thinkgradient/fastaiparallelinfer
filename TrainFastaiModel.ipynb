# %%
# Ensure edits to libraries are loaded and plotting is shown in the notebook.
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# !pip install bqplot
# Out:
# Collecting bqplot
#   Downloading https://files.pythonhosted.org/packages/b7/c2/4449c1d05ec005eef244c58474ed09c7a1e30bb67cfece9020f759f69619/bqplot-0.12.1-py2.py3-none-any.whl (4.7MB)
#     100% |████████████████████████████████| 4.7MB 1.8MB/s ta 0:00:01
# Requirement already satisfied: pandas in /home/byteb/anaconda3/lib/python3.7/site-packages (from bqplot) (0.23.4)
# Requirement already satisfied: numpy>=1.10.4 in /home/byteb/anaconda3/lib/python3.7/site-packages (from bqplot) (1.16.2)
# Requirement already satisfied: traitlets>=4.3.0 in /home/byteb/anaconda3/lib/python3.7/site-packages (from bqplot) (4.3.3)
# Collecting ipywidgets>=7.5.0 (from bqplot)
#   Downloading https://files.pythonhosted.org/packages/56/a0/dbcf5881bb2f51e8db678211907f16ea0a182b232c591a6d6f276985ca95/ipywidgets-7.5.1-py2.py3-none-any.whl (121kB)
#     100% |████████████████████████████████| 122kB 2.5MB/s ta 0:00:01
# Collecting traittypes>=0.0.6 (from bqplot)
#   Downloading https://files.pythonhosted.org/packages/9c/d1/8d5bd662703cc1764d986f6908a608777305946fa634d34c470cd4a1e729/traittypes-0.2.1-py2.py3-none-any.whl
# Requirement already satisfied: python-dateutil>=2.5.0 in /home/byteb/anaconda3/lib/python3.7/site-packages (from pandas->bqplot) (2.8.1)
# Requirement already satisfied: pytz>=2011k in /home/byteb/anaconda3/lib/python3.7/site-packages (from pandas->bqplot) (2019.3)
# Requirement already satisfied: ipython-genutils in /home/byteb/anaconda3/lib/python3.7/site-packages (from traitlets>=4.3.0->bqplot) (0.2.0)
# Requirement already satisfied: decorator in /home/byteb/anaconda3/lib/python3.7/site-packages (from traitlets>=4.3.0->bqplot) (4.4.1)
# Requirement already satisfied: six in /home/byteb/anaconda3/lib/python3.7/site-packages (from traitlets>=4.3.0->bqplot) (1.13.0)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /home/byteb/anaconda3/lib/python3.7/site-packages (from ipywidgets>=7.5.0->bqplot) (7.9.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/byteb/anaconda3/lib/python3.7/site-packages (from ipywidgets>=7.5.0->bqplot) (5.1.0)
# Collecting widgetsnbextension~=3.5.0 (from ipywidgets>=7.5.0->bqplot)
#   Downloading https://files.pythonhosted.org/packages/6c/7b/7ac231c20d2d33c445eaacf8a433f4e22c60677eb9776c7c5262d7ddee2d/widgetsnbextension-3.5.1-py2.py3-none-any.whl (2.2MB)
#     100% |████████████████████████████████| 2.2MB 932kB/s ta 0:00:01
# Requirement already satisfied: nbformat>=4.2.0 in /home/byteb/anaconda3/lib/python3.7/site-packages (from ipywidgets>=7.5.0->bqplot) (4.4.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /home/byteb/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.0->bqplot) (2.0.10)
# Requirement already satisfied: pygments in /home/byteb/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.0->bqplot) (2.5.1)
# Requirement already satisfied: pickleshare in /home/byteb/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.0->bqplot) (0.7.5)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /home/byteb/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.0->bqplot) (4.7.0)
# Requirement already satisfied: backcall in /home/byteb/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.0->bqplot) (0.1.0)
# Requirement already satisfied: jedi>=0.10 in /home/byteb/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.0->bqplot) (0.15.1)
# Requirement already satisfied: setuptools>=18.5 in /home/byteb/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.0->bqplot) (42.0.1)
# Requirement already satisfied: jupyter-client in /home/byteb/anaconda3/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->bqplot) (5.2.4)
# Requirement already satisfied: tornado>=4.2 in /home/byteb/anaconda3/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->bqplot) (6.0.2)
# Requirement already satisfied: notebook>=4.4.1 in /home/byteb/anaconda3/lib/python3.7/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (5.7.8)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/byteb/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.0->bqplot) (3.2.0)
# Requirement already satisfied: jupyter-core in /home/byteb/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.0->bqplot) (4.4.0)
# Requirement already satisfied: wcwidth in /home/byteb/anaconda3/lib/python3.7/site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.0->bqplot) (0.1.7)
# Requirement already satisfied: ptyprocess>=0.5 in /home/byteb/anaconda3/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.0->bqplot) (0.6.0)
# Requirement already satisfied: parso>=0.5.0 in /home/byteb/anaconda3/lib/python3.7/site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.0->bqplot) (0.5.1)
# Requirement already satisfied: pyzmq>=13 in /home/byteb/anaconda3/lib/python3.7/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.5.0->bqplot) (18.0.0)
# Requirement already satisfied: nbconvert in /home/byteb/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (5.6.1)
# Requirement already satisfied: terminado>=0.8.1 in /home/byteb/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (0.8.1)
# Requirement already satisfied: jinja2 in /home/byteb/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (2.10.3)
# Requirement already satisfied: Send2Trash in /home/byteb/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (1.5.0)
# Requirement already satisfied: prometheus-client in /home/byteb/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (0.6.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/byteb/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.0->bqplot) (0.15.6)
# Requirement already satisfied: attrs>=17.4.0 in /home/byteb/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.0->bqplot) (19.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /home/byteb/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.0->bqplot) (0.23)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/byteb/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /home/byteb/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (0.3)
# Requirement already satisfied: bleach in /home/byteb/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (3.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/byteb/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (1.4.2)
# Requirement already satisfied: defusedxml in /home/byteb/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (0.5.0)
# Requirement already satisfied: testpath in /home/byteb/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (0.4.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/byteb/anaconda3/lib/python3.7/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (1.1.1)
# Requirement already satisfied: zipp>=0.5 in /home/byteb/anaconda3/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.0->bqplot) (0.6.0)
# Requirement already satisfied: webencodings in /home/byteb/anaconda3/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (0.5.1)
# Requirement already satisfied: more-itertools in /home/byteb/anaconda3/lib/python3.7/site-packages (from zipp>=0.5->importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.0->bqplot) (7.2.0)
# Installing collected packages: widgetsnbextension, ipywidgets, traittypes, bqplot
#   Found existing installation: widgetsnbextension 3.4.2
#     Uninstalling widgetsnbextension-3.4.2:
#       Successfully uninstalled widgetsnbextension-3.4.2
#   Found existing installation: ipywidgets 7.4.2
#     Uninstalling ipywidgets-7.4.2:
#       Successfully uninstalled ipywidgets-7.4.2
# Successfully installed bqplot-0.12.1 ipywidgets-7.5.1 traittypes-0.2.1 widgetsnbextension-3.5.1

# %%
# !pip install scrapbook
# Out:
# Collecting scrapbook
#   Using cached https://files.pythonhosted.org/packages/eb/22/5c55a90934780daedc2747c8e40bae814adff393da1aca0fae577d13c00d/scrapbook-0.2.0.tar.gz
# Collecting parsel>=1.2.0
#   Using cached https://files.pythonhosted.org/packages/86/c8/fc5a2f9376066905dfcca334da2a25842aedfda142c0424722e7c497798b/parsel-1.5.2-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.10.0 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from scrapbook) (1.11.0)
# Collecting w3lib>=1.19.0
#   Using cached https://files.pythonhosted.org/packages/6a/45/1ba17c50a0bb16bd950c9c2b92ec60d40c8ebda9f3371ae4230c437120b6/w3lib-1.21.0-py2.py3-none-any.whl
# Requirement already satisfied: lxml; python_version != "3.4" in /data/anaconda/envs/py35/lib/python3.5/site-packages (from parsel>=1.2.0->scrapbook) (4.2.5)
# Collecting cssselect>=0.9
#   Using cached https://files.pythonhosted.org/packages/3b/d4/3b5c17f00cce85b9a1e6f91096e1cc8e8ede2e1be8e96b87ce1ed09e92c5/cssselect-1.1.0-py2.py3-none-any.whl
# Building wheels for collected packages: scrapbook
#   Building wheel for scrapbook (setup.py) ... done
#   Created wheel for scrapbook: filename=scrapbook-0.2.0-cp35-none-any.whl size=5686 sha256=4c8fa7d2145ebebe6ea368fa6342692dbc2683e1523d6589bf1f56fda2def0a7
#   Stored in directory: /home/byteb/.cache/pip/wheels/35/4e/3e/b23f6c97e73fdcae44d7a5c8c22024b8e9410c1a20fe61f864
# Successfully built scrapbook
# Installing collected packages: w3lib, cssselect, parsel, scrapbook
# Successfully installed cssselect-1.1.0 parsel-1.5.2 scrapbook-0.2.0 w3lib-1.21.0

# %%
# !pip install fastai
# Out:
# Collecting fastai
#   Downloading https://files.pythonhosted.org/packages/50/6d/9d0d6e17a78b0598d5e8c49a0d03ffc7ff265ae62eca3e2345fab14edb9b/fastai-0.7.0-py3-none-any.whl (112kB)
#      |████████████████████████████████| 122kB 9.9MB/s eta 0:00:01
# Requirement already satisfied: PyYAML in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (3.13)
# Collecting bcolz
#   Downloading https://files.pythonhosted.org/packages/5c/4e/23942de9d5c0fb16f10335fa83e52b431bcb8c0d4a8419c9ac206268c279/bcolz-1.2.1.tar.gz (1.5MB)
#      |████████████████████████████████| 1.5MB 13.8MB/s eta 0:00:01
# Requirement already satisfied: bleach in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (2.1.4)
# Requirement already satisfied: seaborn in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (0.9.0)
# Requirement already satisfied: pandas in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (0.23.4)
# Requirement already satisfied: testpath in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (0.3.1)
# Requirement already satisfied: ipykernel in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (4.10.0)
# Requirement already satisfied: Pygments in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (2.4.2)
# Requirement already satisfied: scipy in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (1.1.0)
# Collecting torch<0.4
#   Downloading https://files.pythonhosted.org/packages/e8/c5/0763a145e051ce7c84c128621693d1c5dfad5a42d551e8d79742261002e2/torch-0.3.1-cp35-cp35m-manylinux1_x86_64.whl (496.4MB)
#      |████████████████████████████████| 496.4MB 18kB/s s eta 0:00:01    |█████▎                          | 81.9MB 59.2MB/s eta 0:00:07     |█████████▉                      | 152.3MB 60.9MB/s eta 0:00:06:00:06     |███████████▊                    | 181.4MB 60.4MB/s eta 0:00:06     |██████████████▏                 | 219.5MB 60.4MB/s eta 0:00:05     |███████████████▌                | 240.1MB 58.8MB/s eta 0:00:05     |████████████████████▍           | 316.5MB 54.8MB/s eta 0:00:04     |█████████████████████           | 326.2MB 54.8MB/s eta 0:00:04████████████████          | 342.2MB 54.8MB/s eta 0:00:03     |███████████████████████▌        | 364.5MB 64.6MB/s eta 0:00:03     |████████████████████████▌       | 380.9MB 64.6MB/s eta 0:00:02     |██████████████████████████████  | 465.3MB 65.9MB/s eta 0:00:01     |██████████████████████████████▏ | 468.5MB 65.9MB/s eta 0:00:01
# Collecting torchtext
#   Downloading https://files.pythonhosted.org/packages/79/ef/54b8da26f37787f5c670ae2199329e7dccf195c060b25628d99e587dac51/torchtext-0.5.0-py3-none-any.whl (73kB)
#      |████████████████████████████████| 81kB 5.8MB/s  eta 0:00:01
# Requirement already satisfied: pyparsing in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (2.4.2)
# Requirement already satisfied: jedi in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (0.12.1)
# Collecting feather-format
#   Downloading https://files.pythonhosted.org/packages/08/55/940b97cc6f19a19f5dab9efef2f68a0ce43a7632f858b272391f0b851a7e/feather-format-0.4.0.tar.gz
# Requirement already satisfied: Jinja2 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (2.10.3)
# Requirement already satisfied: entrypoints in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (0.3)
# Collecting isoweek
#   Downloading https://files.pythonhosted.org/packages/c2/d4/fe7e2637975c476734fcbf53776e650a29680194eb0dd21dbdc020ca92de/isoweek-1.3.3-py2.py3-none-any.whl
# Requirement already satisfied: simplegeneric in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (0.8.1)
# Requirement already satisfied: torchvision in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (0.4.0a0+6b959ee)
# Requirement already satisfied: numpy in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (1.16.2)
# Requirement already satisfied: wcwidth in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (0.1.7)
# Collecting pandas-summary
#   Downloading https://files.pythonhosted.org/packages/f5/20/865d4785f86e86f7ad7ebd52fc14810ef59ef13cd959f1363a2615d1c665/pandas_summary-0.0.7-py2.py3-none-any.whl
# Requirement already satisfied: jsonschema in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (2.6.0)
# Requirement already satisfied: pyzmq in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (17.1.2)
# Requirement already satisfied: graphviz in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (0.8.4)
# Requirement already satisfied: ipywidgets in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (7.5.1)
# Requirement already satisfied: pickleshare in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (0.7.4)
# Requirement already satisfied: sklearn-pandas in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (1.7.0)
# Requirement already satisfied: traitlets in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (4.3.2)
# Requirement already satisfied: pytz in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (2019.3)
# Collecting plotnine
#   Downloading https://files.pythonhosted.org/packages/84/02/b171c828560aea3a5da1efda464230dac3ef4f4834b88e0bd52ad14a08f0/plotnine-0.5.1-py2.py3-none-any.whl (3.6MB)
#      |████████████████████████████████| 3.6MB 43.8MB/s eta 0:00:01
# Requirement already satisfied: widgetsnbextension in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (3.5.1)
# Requirement already satisfied: cycler in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (0.10.0)
# Requirement already satisfied: tqdm in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (4.37.0)
# Requirement already satisfied: MarkupSafe in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (1.0)
# Requirement already satisfied: tornado in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (5.1.1)
# Requirement already satisfied: certifi in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (2018.8.24)
# Collecting opencv-python
#   Downloading https://files.pythonhosted.org/packages/59/dc/f4a3c35673512e3bfaa48c4e3b6c1bc3e262a8a2bfc9ffef986780d15ad3/opencv_python-4.1.2.30-cp35-cp35m-manylinux1_x86_64.whl (28.3MB)
#      |████████████████████████████████| 28.3MB 19.7MB/s eta 0:00:01    |█████▎                          | 4.7MB 19.7MB/s eta 0:00:02
# Requirement already satisfied: ipython-genutils in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (0.2.0)
# Requirement already satisfied: webencodings in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (0.5.1)
# Requirement already satisfied: jupyter in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (1.0.0)
# Requirement already satisfied: decorator in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (4.4.1)
# Requirement already satisfied: html5lib in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (1.0.1)
# Requirement already satisfied: Pillow in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (5.2.0)
# Requirement already satisfied: matplotlib in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (3.0.0)
# Requirement already satisfied: python-dateutil in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (2.8.0)
# Requirement already satisfied: ptyprocess in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (0.6.0)
# Requirement already satisfied: ipython in /data/anaconda/envs/py35/lib/python3.5/site-packages (from fastai) (6.5.0)
# Requirement already satisfied: six in /data/anaconda/envs/py35/lib/python3.5/site-packages (from bleach->fastai) (1.11.0)
# Requirement already satisfied: jupyter_client in /data/anaconda/envs/py35/lib/python3.5/site-packages (from ipykernel->fastai) (5.3.3)
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/4b/7b/97cdb2425ae93cdb3231ba38edb759bb311751c16bebda242508f9a79682/sentencepiece-0.1.85-cp35-cp35m-manylinux1_x86_64.whl (1.0MB)
#      |████████████████████████████████| 1.0MB 39.0MB/s eta 0:00:01
# Requirement already satisfied: requests in /data/anaconda/envs/py35/lib/python3.5/site-packages (from torchtext->fastai) (2.22.0)
# Requirement already satisfied: parso>=0.3.0 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from jedi->fastai) (0.5.1)
# Requirement already satisfied: pyarrow>=0.4.0 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from feather-format->fastai) (0.11.1)
# Requirement already satisfied: nbformat>=4.2.0 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from ipywidgets->fastai) (4.4.0)
# Requirement already satisfied: scikit-learn>=0.15.0 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from sklearn-pandas->fastai) (0.20.0)
# Collecting mizani>=0.5.2
#   Downloading https://files.pythonhosted.org/packages/d6/57/dd70eedf5d85cb328f73bbc661b7680f15bfebb07d8dabc3bda7de9faa7c/mizani-0.5.4-py2.py3-none-any.whl (58kB)
#      |████████████████████████████████| 61kB 4.1MB/s  eta 0:00:01
# Requirement already satisfied: patsy>=0.4.1 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from plotnine->fastai) (0.5.1)
# Collecting descartes>=1.1.0
#   Downloading https://files.pythonhosted.org/packages/e5/b6/1ed2eb03989ae574584664985367ba70cd9cf8b32ee8cad0e8aaeac819f3/descartes-1.1.0-py3-none-any.whl
# Requirement already satisfied: statsmodels>=0.8.0 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from plotnine->fastai) (0.9.0)
# Requirement already satisfied: notebook>=4.4.1 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from widgetsnbextension->fastai) (5.6.0)
# Requirement already satisfied: nbconvert in /data/anaconda/envs/py35/lib/python3.5/site-packages (from jupyter->fastai) (5.5.0)
# Requirement already satisfied: jupyter-console in /data/anaconda/envs/py35/lib/python3.5/site-packages (from jupyter->fastai) (5.2.0)
# Requirement already satisfied: qtconsole in /data/anaconda/envs/py35/lib/python3.5/site-packages (from jupyter->fastai) (4.5.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from matplotlib->fastai) (1.0.1)
# Requirement already satisfied: backcall in /data/anaconda/envs/py35/lib/python3.5/site-packages (from ipython->fastai) (0.1.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /data/anaconda/envs/py35/lib/python3.5/site-packages (from ipython->fastai) (4.6.0)
# Requirement already satisfied: setuptools>=18.5 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from ipython->fastai) (40.2.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.15 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from ipython->fastai) (1.0.15)
# Requirement already satisfied: jupyter-core in /data/anaconda/envs/py35/lib/python3.5/site-packages (from jupyter_client->ipykernel->fastai) (4.5.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from requests->torchtext->fastai) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from requests->torchtext->fastai) (2.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from requests->torchtext->fastai) (1.23)
# Collecting palettable
#   Downloading https://files.pythonhosted.org/packages/ca/46/5198aa24e61bb7eef28d06cb69e56bfa1942f4b6807d95a0b5ce361fe09b/palettable-3.3.0-py2.py3-none-any.whl (111kB)
#      |████████████████████████████████| 112kB 51.9MB/s eta 0:00:01
# Requirement already satisfied: Send2Trash in /data/anaconda/envs/py35/lib/python3.5/site-packages (from notebook>=4.4.1->widgetsnbextension->fastai) (1.5.0)
# Requirement already satisfied: terminado>=0.8.1 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from notebook>=4.4.1->widgetsnbextension->fastai) (0.8.1)
# Requirement already satisfied: prometheus-client in /data/anaconda/envs/py35/lib/python3.5/site-packages (from notebook>=4.4.1->widgetsnbextension->fastai) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from nbconvert->jupyter->fastai) (1.4.2)
# Requirement already satisfied: defusedxml in /data/anaconda/envs/py35/lib/python3.5/site-packages (from nbconvert->jupyter->fastai) (0.6.0)
# Requirement already satisfied: mistune>=0.8.1 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from nbconvert->jupyter->fastai) (0.8.3)
# Building wheels for collected packages: bcolz, feather-format
#   Building wheel for bcolz (setup.py) ... done
#   Created wheel for bcolz: filename=bcolz-1.2.1-cp35-cp35m-linux_x86_64.whl size=2953050 sha256=3eaccc9048f1cc519f7c57d241386791580c39c3be0c830b2605fe84c28058d2
#   Stored in directory: /home/byteb/.cache/pip/wheels/9f/78/26/fb8c0acb91a100dc8914bf236c4eaa4b207cb876893c40b745
#   Building wheel for feather-format (setup.py) ... done
#   Created wheel for feather-format: filename=feather_format-0.4.0-cp35-none-any.whl size=4250 sha256=a6d57b4abb027816ba6949a2fb29ce7da7f6e3dec88c4a2f832461372add0c87
#   Stored in directory: /home/byteb/.cache/pip/wheels/85/7d/12/2dfa5c0195f921ac935f5e8f27deada74972edc0ae9988a9c1
# Successfully built bcolz feather-format
# Installing collected packages: bcolz, torch, sentencepiece, torchtext, feather-format, isoweek, pandas-summary, palettable, mizani, descartes, plotnine, opencv-python, fastai
#   Found existing installation: torch 1.2.0
#     Uninstalling torch-1.2.0:
#       Successfully uninstalled torch-1.2.0
# Successfully installed bcolz-1.2.1 descartes-1.1.0 fastai-0.7.0 feather-format-0.4.0 isoweek-1.3.3 mizani-0.5.4 opencv-python-4.1.2.30 palettable-3.3.0 pandas-summary-0.0.7 plotnine-0.5.1 sentencepiece-0.1.85 torch-0.3.1 torchtext-0.5.0

# %%
import sys
sys.path.append("../../")

import numpy as np
from pathlib import Path
import scrapbook as sb

# fastai and torch
import fastai
from fastai.metrics import accuracy
from fastai.vision import (
    models, ImageList, imagenet_stats, partial, cnn_learner, ClassificationInterpretation, to_np,
)

# local modules
from utils_cv.classification.model import TrainMetricsRecorder
from utils_cv.classification.plot import plot_pr_roc_curves
from utils_cv.classification.widget import ResultsWidget
from utils_cv.classification.data import Urls
from utils_cv.common.data import unzip_url
from utils_cv.common.gpu import db_num_workers, which_processor

print("Fast.ai version = {fastai.__version__}")
which_processor()
# Out:
# Fast.ai version = {fastai.__version__}
# Torch is using GPU: Tesla K80

# %%
DATA_PATH     = unzip_url(Urls.fridge_objects_path, exist_ok=True)
EPOCHS        = 10
LEARNING_RATE = 1e-4
IM_SIZE       = 300

BATCH_SIZE    = 16
ARCHITECTURE  = models.resnet18

# %%
path = Path(DATA_PATH)
path.ls()
# Out:
# [PosixPath('/data/home/byteb/notebooks/batchinference/data/fridgeObjects/carton'),
#  PosixPath('/data/home/byteb/notebooks/batchinference/data/fridgeObjects/water_bottle'),
#  PosixPath('/data/home/byteb/notebooks/batchinference/data/fridgeObjects/milk_bottle'),
#  PosixPath('/data/home/byteb/notebooks/batchinference/data/fridgeObjects/can')]

# %% [markdown]
# # Load Images
#
# In fast.ai, an `ImageDataBunch` can easily use multiple images (mini-batches) during training time. We create the `ImageDataBunch` by using [data_block apis](https://docs.fast.ai/data_block.html).
#
# For training and validation, we randomly split the data in an `8:2` ratio, holding 80% of the data for training and 20% for validation. One can also created dedicated train-test splits e.g. by placing the image structure shown above into parent-folders "train" and "valid" and then using [.split_by_folder()](https://docs.fast.ai/data_block.html#ItemList.split_by_folder) instead of .split_by_rand_pct() below.

# %%
data = (
    ImageList.from_folder(path)
    .split_by_rand_pct(valid_pct=0.2, seed=10)
    .label_from_folder()
    .transform(size=IM_SIZE)
    .databunch(bs=BATCH_SIZE, num_workers = db_num_workers())
    .normalize(imagenet_stats)
)

# %%
data.show_batch(rows=3, figsize=(15,11))

# %%
print(f'number of classes: {data.c}')
print(data.classes)
# Out:
# number of classes: 4
# ['can', 'carton', 'milk_bottle', 'water_bottle']

# %%
data.batch_stats
# Out:
# <bound method ImageDataBunch.batch_stats of ImageDataBunch;
#
# Train: LabelList (108 items)
# x: ImageList
# Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300)
# y: CategoryList
# carton,carton,carton,carton,carton
# Path: /data/home/byteb/notebooks/batchinference/data/fridgeObjects;
#
# Valid: LabelList (26 items)
# x: ImageList
# Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300)
# y: CategoryList
# water_bottle,water_bottle,water_bottle,can,can
# Path: /data/home/byteb/notebooks/batchinference/data/fridgeObjects;
#
# Test: None>

# %% [markdown]
# # Train a Model

# %% [markdown]
# For this image classifier, we use a **ResNet18** convolutional neural network (CNN) architecture. You can find more details about ResNet from [here](https://arxiv.org/abs/1512.03385).
#
# When training CNN, there are almost an infinite number of ways to construct the model architecture. We need to determine how many and what type of layers to include and how many nodes make up each layer. Other hyperparameters that control the training of those layers are also important and add to the overall complexity of neural net methods. With fast.ai, we use the `create_cnn` function to specify the model architecture and performance metric. We will use a transfer learning approach to reuse the CNN architecture and initialize the model parameters used to train on [ImageNet](http://www.image-net.org/).
#
# In this work, we use a custom callback `TrainMetricsRecorder` to track the model accuracy on the training set as we tune the model. This is for instruction only, as the standard approach in `fast.ai` [recorder class](https://docs.fast.ai/basic_train.html#Recorder) only supports tracking model accuracy on the validation set.

# %%
learn = cnn_learner(
    data,
    ARCHITECTURE,
    metrics=[accuracy],
    callback_fns=[partial(TrainMetricsRecorder, show_graph=True)]
)

# %%
learn.unfreeze()

# %%
learn.fit(EPOCHS, LEARNING_RATE)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>train_accuracy</th>
#       <th>valid_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.387334</td>
#       <td>2.242829</td>
#       <td>0.489583</td>
#       <td>0.269231</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.150318</td>
#       <td>1.022673</td>
#       <td>0.677083</td>
#       <td>0.653846</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.820866</td>
#       <td>0.715048</td>
#       <td>0.916667</td>
#       <td>0.807692</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.619237</td>
#       <td>0.645389</td>
#       <td>0.958333</td>
#       <td>0.769231</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.484262</td>
#       <td>0.593075</td>
#       <td>0.968750</td>
#       <td>0.769231</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.390708</td>
#       <td>0.521111</td>
#       <td>0.989583</td>
#       <td>0.807692</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.321947</td>
#       <td>0.490508</td>
#       <td>1.000000</td>
#       <td>0.807692</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.271440</td>
#       <td>0.464632</td>
#       <td>0.989583</td>
#       <td>0.846154</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.228570</td>
#       <td>0.471814</td>
#       <td>1.000000</td>
#       <td>0.807692</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.195971</td>
#       <td>0.460522</td>
#       <td>0.989583</td>
#       <td>0.846154</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>

# %%
# You can plot loss by using the default callback Recorder.
learn.recorder.plot_losses()

# %% [markdown]
# # Validate the model
#
# To validate the model, calculate the model accuracy using the validation set.

# %%
_, validation_accuracy = learn.validate(learn.data.valid_dl, metrics=[accuracy])
print(f'Accuracy on validation set: {100*float(validation_accuracy):3.2f}')
# Out:
# Accuracy on validation set: 84.62

# %%
interp = ClassificationInterpretation.from_learner(learn)
# Get prediction scores. We convert tensors to numpy array to plot them later.
pred_scores = to_np(interp.preds)

# %%
# True labels of the validation set. We convert to numpy array for plotting.
true_labels = to_np(interp.y_true)
plot_pr_roc_curves(true_labels, pred_scores, data.classes)

# %%
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(9, figsize=(15,11), heatmap=True)

# %% [markdown]
# # Save Model

# %%
learn.model.cuda()
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (1): Sequential(
#     (0): AdaptiveConcatPool2d(
#       (ap): AdaptiveAvgPool2d(output_size=1)
#       (mp): AdaptiveMaxPool2d(output_size=1)
#     )
#     (1): Flatten()
#     (2): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=1024, out_features=512, bias=True)
#     (5): ReLU(inplace=True)
#     (6): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.5, inplace=False)
#     (8): Linear(in_features=512, out_features=4, bias=True)
#   )
# )

# %%
## Save model as .pth file
learn.save("/home/byteb/notebooks/batchinference/models/model-resnet18")

# %%
## Save model as pickle (.pkl) file
learn.export(file = Path("/home/byteb/notebooks/batchinference/models/model-resnet18.pkl"))
